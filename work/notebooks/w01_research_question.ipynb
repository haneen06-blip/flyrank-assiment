# %% [markdown]
# <a href="https://colab.research.google.com/github/haneen06-blip/flyrank-assiment/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/haneen06-blip/flyrank-assiment/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Refresh / Content Opportunity Scoring lane
# because it focuses on identifying and prioritizing pages that may need content review using observable signals. This lane matches the starter notebooks, where I explored ranking pages using simple rules and machine learning models

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The project helps identify which pages may need refreshing and should be reviewed first. The final decision is made by the page owner or content team. A wrong recommendation can waste time and effort by refreshing pages that do not need changes, and it may even negatively affect their performance. On the other hand, missing a page that needs improvement may leave it underperforming

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 pages. I found 16,262 pages with a declining trend, and 1,372 pages that have a combination of declining trend, low impressions, and weak position tiers. These numbers show that there are pages with performance signals worth investigating

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df.head(10)
df["position_tier"].value_counts()
df["impression_tier"].value_counts()
refresh_candidates = df[
    (df["trend_direction"].str.lower() == "down") &
    (df["impression_tier"] == "low") &
    (df["position_tier"].isin(["deep", "page_3_5"]))
]

print("Number of possible refresh candidates:", len(refresh_candidates))

refresh_candidates.head()
# Out:
# Number of possible refresh candidates: 1372
#               content_id          client_id  search_volume  competition  \
# 14  content_91067a14431a  client_6208ef0f77            0.0         0.00
# 39  content_4595e8704e07  client_8527a891e2           90.0         0.06
# 44  content_793b7376a0e5  client_8527a891e2            0.0         0.00
# 47  content_40cb4af260c0  client_f369cb89fc            0.0         0.00
# 63  content_d5d3c2e98937  client_f74efabef1           40.0         0.50
#
#    competition_level   cpc     content_type    main_intent  word_count  \
# 14               LOW  0.00  keyword article  informational      2802.0
# 39               LOW  0.03  keyword article  informational      3666.0
# 44               LOW  0.00  keyword article  informational      3842.0
# 47               LOW  0.00  keyword article  informational      3086.0
# 63            MEDIUM  3.09  keyword article  transactional      3319.0
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work will identify pages with performance signals and provide decision-support recommendations. It will not guarantee that a page will improve after a refresh, because the result is not certain and depends on different factors

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
